# %% [markdown]
# # Question 1 - a:
#
# The CIFAR-10 dataset is a famous computer vision dataset. It consists of 60000 32x32 color images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Download the dataset using this link: https://www.cs.toronto.edu/~kriz/cifar.html
#
#     a) Plot 5 random images inside the training set and 5 random images inside the testing set.

# %%
#To ignore tensorflow's numpy related warnings
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Libraries
#
# We used the CIFAR-10 dataset provided with tensorflow's keras. Since our goal is to plot images, we utilized the matplotlib for the plotting task. We implemented the random library to obtain random values for data entry selection.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
assert X_train.shape == (50000, 32, 32, 3)
assert X_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Plot 5 training images and 5 test images.
# The first five images are picked randomly from training set,
# Last five images are selected randomly from test set.
plt.figure(figsize=(16, 6))
for i in range(10):
    if i < 5:
        n = random.randrange(0,50000)
        plt.subplot(2, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(X_train[n])
        plt.xlabel(labels[y_train[n][0]])
    else:
        n = random.randrange(0,10000)
        plt.subplot(2, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(X_test[n])
        plt.xlabel(labels[y_test[n][0]])
plt.show()
